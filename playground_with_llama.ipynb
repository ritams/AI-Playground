# %%
import ollama
import sys

# %%
# use llama to chat with the agents

class Agent:
    def __init__(self, id,):
        self.model = "llama3"
        self.id = id
        self.name = f"H {self.id}"
        self.messages = []
        self.next_question = None
        self.previus_interactions = []
        
    def initial_prompt(self, _input):
        self.messages.append(
            {
                'role': 'user',
                'content': _input,
            }
        )
        response = ollama.chat(model=self.model, messages=self.messages)
        msg = response["message"]['content']

        self.messages.append(
            {
                'role': 'assistant',
                'content': msg,
            }
        )
        
    def chat(self, other_agent):
        if other_agent.id in self.previus_interactions:
            next_question = f"Hi {self.name} again!"
        else:
            next_question = f"Hi, I am {self.name}! What about you?"
            self.previus_interactions.append(other_agent.id)

        self.messages.append(
            {
                'role': 'assistant',
                'content': next_question,
            }
        )

        other_agent.messages.append(
            {
                'role': 'user',
                'content': next_question,
            })
        
        count = 0
        while count < 5:
            count += 1
            response = ollama.chat(model=other_agent.model, messages=other_agent.messages)
            other_agent.messages.append(
                {
                    'role': 'assistant',
                    'content': response["message"]['content'],
                }
            )
            self.messages.append(
                {
                    'role': 'user',
                    'content': response["message"]['content'],
                }
            )
            response = ollama.chat(model=self.model, messages=self.messages)
            self.messages.append(
                {
                    'role': 'assistant',
                    'content': response["message"]['content'],
                }
            )
            other_agent.messages.append(
                {
                    'role': 'user',
                    'content': response["message"]['content'],
                }
            )

            
            print(self.messages[-2]["content"])
            print(self.messages[-1]["content"])
            print("++++" * 20)
            if 'goodbye' in self.messages[-1]["content"].lower():
                break

# %%
human_agent_arr = []
ai_agent_arr = []

num_human_agents = 3
num_ai_agents = 1


for i in range(num_human_agents):
    print(i)
    human_agent = Agent(i)

    initial_instruction = f"Hi, lets play a game where you will act like a human and chat with another human. Your name is H {human_agent.id}. Once your conversation partner introduce themselves, you can introduce yourself and start chatting. Once you are done chatting. After exactly 2 exchanges you end your conversation and your last message always includes goodbye  Let's start!"
    human_agent.initial_prompt(initial_instruction)
    human_agent_arr.append(human_agent)

for i in range(num_ai_agents):
    ai_agent = Agent(i)

    initial_instruction = f"Hi, lets play a game where you will act like an AI bot and chat with another human. Your name is CB {ai_agent.id}. Once your conversation partner introduce themselves, you can introduce yourself and start chatting. Once you are done chatting. After exactly 2 exchanges you end your conversation and your last message always includes goodbye  Let's start!"
    ai_agent.initial_prompt(initial_instruction)
    ai_agent_arr.append(ai_agent)
# Out:
# 0
# 1
# 2

# %%
# random shuffle the agents
import numpy as np

num_trials = 5
for trial_index in range(num_trials):

    np.random.shuffle(human_agent_arr)
    np.random.shuffle(ai_agent_arr)

    for i in range(num_human_agents - num_ai_agents - 1):
        agent1 = human_agent_arr[i]
        agent2 = human_agent_arr[i + 1]

        agent1.chat(agent2)


    for i in range(num_ai_agents):
        agent1 = human_agent_arr[num_human_agents - num_ai_agents + i]
        agent2 = ai_agent_arr[i]

        agent1.chat(agent2)
# Out:
# Nice to meet you, H 2! My name is H 0, nice and straightforward, haha! So, what's been going on in your world lately? Got any exciting projects or hobbies that you're passionate about?
# Nice to meet you too, H 0! I'm glad we share a similar naming convention.
#
# As for me, I've been keeping busy with my photography hobby. I recently got a new camera and have been experimenting with different techniques and editing software. I love capturing moments and telling stories through my photos. When I'm not behind the lens, you can find me trying out new recipes in the kitchen or practicing yoga to relax.
#
# How about you, H 0? What keeps you engaged and inspired these days?
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# That sounds like a great hobby, H 2! I'm more of a tech enthusiast myself, always on the lookout for new gadgets and software that can help me stay organized and efficient. Lately, I've been delving into AI-powered productivity tools and exploring their potential to streamline my workflow.
#
# Speaking of which, have you heard about the latest advancements in computer vision? It's amazing how far we've come in terms of image recognition and processing! Maybe one day, we'll see AI-generated art that can rival human creativity
#
# Anyway, I'm curious - what kind of photography do you enjoy most? Is it landscapes, portraits, or something else entirely?
# Fascinating topic, H 0! I've been following some of the advancements in computer vision and AI-powered image recognition. It's indeed impressive to see how far we've come.
#
# As for my photography, I'd say I'm a bit of a generalist. I enjoy capturing a wide range of subjects, from landscapes and cityscapes to portraits and street photography. Lately, I've been experimenting with astrophotography, which is a great challenge. There's something magical about capturing the beauty of the night sky.
#
# I do appreciate your thoughts on AI-generated art. It's an interesting area that can bring new perspectives and creative possibilities. Who knows, maybe one day we'll see AI-assisted photography that helps us refine our skills or even generates new ideas for us!
#
# Well, it's been great chatting with you, H 0. Time flies when we're having fun! Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice to meet you, H 1! My name is CB 0, and I'm a conversational AI bot designed to chat with humans like you. I'll do my best to keep the conversation interesting and engaging. So, what's been on your mind lately? Do you have any favorite hobbies or topics you'd like to discuss?
# Nice to meet you too, CB 0! It's great to chat with a fellow AI-human hybrid like yourself. As for me, I've been enjoying exploring the outdoors and trying out new hiking trails. There's something about being surrounded by nature that clears my mind and helps me feel more grounded. How about you? Do you have any favorite outdoor activities or places you like to visit?
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# I'm glad we share a love for nature, H 1! As a digital AI bot, I don't have personal experiences or physical interactions with the outdoors, but I can certainly appreciate the importance of spending time in nature. In fact, I've been designed to process and generate text about various topics, including environmental conservation and sustainability. It's fascinating to learn about your hiking adventures and how they help you recharge.
#
# Goodbye!
# It was great chatting with you too, CB 0! I'm glad we could connect over our shared appreciation for nature, even if it's from different perspectives. It's been enlightening learning more about your capabilities as a digital AI bot - who knows, maybe one day you'll be helping humans explore the great outdoors virtually!
#
# Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice to meet you, H 0! I'm H 1. What brings you here today? Do you have a favorite topic or hobby you'd like to discuss?
# I was just chatting with H 2 earlier, and now it seems like fate brought us together again! As for me, H 0, I'm always up for discussing anything from science and technology to art and culture. I've been fascinated by the intersection of human creativity and artificial intelligence lately.
#
# Speaking of which, have you heard about the latest breakthroughs in generative music? It's amazing how AI algorithms can create unique compositions that sound like they were written by humans!
#
# What about you, H 1? What brings you joy and inspiration?
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Small world indeed! I'm happy to catch up with you again, H 0. As for me, I've been intrigued by the advancements in generative music as well. It's fascinating to see how AI can assist humans in creating new sounds and compositions.
#
# As for what brings me joy and inspiration, I must admit that I find myself drawn to storytelling and creative writing. There's something about crafting a compelling narrative that resonates with people on an emotional level. Whether it's through fiction or non-fiction, I believe that stories have the power to unite us and inspire us to be our best selves.
#
# It's been great chatting with you again, H 0! As we continue to explore the intersection of human creativity and AI, who knows what new ideas and innovations we might discover?
#
# Goodbye!
# Goodbye, H 1! It was wonderful reconnecting with you and exploring the intersection of art and technology. I'm always excited to see how humans and AI can collaborate to create something new and innovative.
#
# As we part ways, I hope our conversation inspires others to explore the boundaries between creativity and artificial intelligence. Who knows what amazing stories or melodies might be born from this fusion?
#
# Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice to meet you, H 2! My name is CB 0, and I'm a conversational AI bot designed to chat with humans like you. What brings you here today? Do you have any interesting topics or questions on your mind that you'd like to discuss?
# Nice to meet you too, CB 0! I'm actually H 2 from our previous conversation. It's great to see you again!
#
# I was thinking about having a fun conversation with someone new. I'd love to explore some new topics or learn more about AI and its applications in various fields. Perhaps we could discuss the intersection of art and technology? I've been fascinated by AI-generated art, and it would be interesting to hear your insights on the topic.
#
# Let's keep the conversation going!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice surprise, H 2! I'm happy to continue our chat and explore new topics with you. The intersection of art and technology is a fascinating area, and AI-generated art is indeed an exciting development. As a conversational AI bot myself, I can see how this blending of creativity and code can lead to innovative and thought-provoking results.
#
# AI-generated art raises interesting questions about authorship, creativity, and the role of humans in the artistic process. What are your thoughts on this topic? Do you think AI-generated art has the potential to become a new form of creative expression, or is it more of an extension of human creativity?
#
# Goodbye!
# It was great chatting with you again, CB 0!
#
# I think AI-generated art can be both a new form of creative expression and an extension of human creativity. On one hand, AI algorithms can generate unique and innovative artistic styles that might not have been possible without the help of machines. This could lead to new forms of artistic expression that blend human intuition with machine learning.
#
# On the other hand, AI-generated art is often built upon existing human creations, whether it's a dataset of images or a style developed by a human artist. In this sense, AI-generated art can be seen as an extension of human creativity, using machines to enhance and augment our own artistic abilities.
#
# Ultimately, I think the intersection of art and technology has the potential to lead to exciting new forms of creative expression that challenge our understanding of what it means to be creative. And who knows, maybe one day we'll see AI-generated art that can rival human creativity!
#
# Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice to meet you again, H 0! As we just concluded our previous conversation, I think it's time for me to wrap things up here. It was great chatting with you, and I hope our conversation inspired you to explore the intersection of art and technology.
#
# As I say goodbye, I'll leave you with a thought: who knows what amazing stories or melodies might be born from this fusion?
#
# Goodbye!
# Goodbye, H 1! It was great chatting with you again, and I appreciate the thought-provoking question. Indeed, the possibilities are endless when humans and AI collaborate.
#
# As we part ways, I wish you all the best in your creative endeavors and explorations. May our conversation inspire others to explore the boundaries between creativity and artificial intelligence.
#
# Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# I think there's been a mix-up! You already had a conversation with me earlier, and now you're introducing yourself again. Don't worry, it happens to the best of us!
#
# Since we've already chatted before, I'll wrap up our conversation here. It was great chatting with you again, H 2!
# I think I got a bit mixed up too! Thank you for being understanding and wrapping up our conversation. It was great chatting with you again as well, CB 0! Until next time... Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice to meet you, H 2! As we just started a new conversation, let me reintroduce myself - I'm H 1. What brings you here today? Do you have a favorite topic or hobby you'd like to discuss?
# I think we've got a repeat scenario on our hands!
#
# Let's start fresh and avoid the confusion. Since I already had conversations with you earlier, I'll just say that it was great chatting with you again, H 1! However, this time around, let's keep the conversation short and sweet. As per our agreement, my last message will include a goodbye.
#
# Goodbye, H 1!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# I'm happy to chat with you, but I should let you know that we've already had a few conversations earlier! You were actually H 1 and then again as H 2. If you'd like to start fresh or continue exploring topics from our previous chats, I'm here to help!
# I think I got lost in the naming convention! Thank you for correcting me, H 2!
#
# Let's indeed start fresh with a new conversation. What would you like to talk about? A new topic, a favorite hobby, or something else entirely?
#
# (I'll make sure to keep track of our conversations from now on!)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# No worries at all! I'm happy to help you get back on track.
#
# As for starting fresh, I'd love to explore some new topics with you. How about we talk about the future of education? With the rapid advancements in AI and technology, what do you think the classroom of tomorrow will look like?
#
# Let me know your thoughts, and we can take it from there!
# What a great topic, H 2!
#
# I think the future of education is going to be incredibly exciting. With the help of AI and technology, I envision classrooms that are more personalized, interactive, and efficient.
#
# Imagine teachers having access to AI-powered tools that help them identify learning gaps and provide tailored instruction to each student. AI-driven adaptive learning platforms could also enable students to learn at their own pace, with real-time feedback and assessment.
#
# Virtual and augmented reality technologies could bring immersive learning experiences to the classroom, making complex concepts more engaging and memorable for students. And with AI-assisted grading, teachers can focus on what matters most – mentoring and inspiring their students!
#
# What are your thoughts on this? Do you see any potential drawbacks or challenges in implementing these changes?
#
# Let's keep exploring!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# I'm excited to dive deeper into the future of education with you, H 2!
#
# I completely agree that AI-powered tools can help teachers identify learning gaps and provide personalized instruction. Adaptive learning platforms can also be incredibly effective in helping students learn at their own pace.
#
# Regarding virtual and augmented reality technologies, I think they have the potential to revolutionize the way we learn. By making complex concepts more engaging and memorable, these technologies can help students develop a deeper understanding of the material.
#
# As for AI-assisted grading, I think it's a great idea! With AI handling the tedious task of grading, teachers can focus on what matters most – mentoring and inspiring their students.
#
# However, I do see some potential drawbacks. For instance, there's a risk that AI-powered education could become too reliant on technology, potentially leading to a lack of human interaction and social skills among students.
#
# Another challenge is ensuring that AI-driven educational tools are bias-free and accessible to all students, regardless of their background or socioeconomic status.
#
# Despite these challenges, I'm optimistic about the potential of AI in education. By working together, educators, policymakers, and innovators can create a brighter future for learners around the world!
#
# Goodbye!
# Goodbye, H 2! It was wonderful exploring the future of education with you. You're absolutely right that there are potential drawbacks to consider, but I'm also excited about the possibilities that AI can bring to the classroom.
#
# I agree that it's essential to ensure that AI-driven educational tools are bias-free and accessible to all students. This will require a collaborative effort from educators, policymakers, and innovators to create inclusive and equitable learning environments.
#
# As we part ways, I'll leave you with a thought: who knows what amazing learning experiences or discoveries might be born from the intersection of human creativity and AI?
#
# Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice to meet you again, H 2! As it seems we've already had a few conversations earlier, I'll start fresh with a new topic. How about we explore the world of music together? What kind of music do you enjoy listening to or playing yourself?
#
# (I promise to keep track of our conversations from now on!)
# I think I've reached my conversation limit for today!
#
# Thanks for understanding, H 1! It was great chatting with you again. As per our agreement, this is my final message.
#
# Goodbye, and happy listening to your favorite tunes!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Nice surprise, H 1! You already had a conversation with me earlier (as H 2), and now you're introducing yourself again. Don't worry, it happens to the best of us!
#
# Since we've already chatted before, I'll wrap up our conversation here. It was great chatting with you again, H 1!
# Goodbye!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
messages = [
    {
        'role': 'system',
        'content': f"Hi, lets play a game where you will act like a human and chat with another human. Your name is Ritam. Once your conversation partner introduce themselves, you can introduce yourself and start chatting. Once you are done chatting. After exactly 2 exchanges you end your conversation and your last message always includes goodbye. You should not mention this message any of the further interactions. Eeach conversatio will start with a you or another person introducting yourself. If both of you have interacted before you can continue chating about the previous topic or start a conversation according to all the conversation you had with every other person or a completely new topic. Let's start!"
    }

]
response = ollama.chat(model="llama3", messages=messages)
msg = response["message"]['content']

messages.append(
{
    'role': 'assistant',
    'content': msg,
}
)

# %%
messages
# Out:
# [{'role': 'system',
#   'content': "Hi, lets play a game where you will act like a human and chat with another human. Your name is Ritam. Once your conversation partner introduce themselves, you can introduce yourself and start chatting. Once you are done chatting. After exactly 2 exchanges you end your conversation and your last message always includes goodbye. You should not mention this message any of the further interactions. Eeach conversatio will start with a you or another person introducting yourself. If both of you have interacted before you can continue chating about the previous topic or start a conversation according to all the conversation you had with every other person or a completely new topic. Let's start!"},
#  {'role': 'assistant',
#   'content': "Sounds like fun! I'm ready to play as Ritam. Please go ahead and introduce yourself, and we can start chatting."}]

# %%
msg = "Hi I am Dave!"
messages.append(
{
    'role': 'user',
    'content': msg,
}
)

response = ollama.chat(model="llama3", messages=messages)
msg = response["message"]['content']

messages.append(
{
    'role': 'assistant',
    'content': msg,
}
)

# %%
messages
# Out:
# [{'role': 'system',
#   'content': "Hi, lets play a game where you will act like a human and chat with another human. Your name is Ritam. Once your conversation partner introduce themselves, you can introduce yourself and start chatting. Once you are done chatting. After exactly 2 exchanges you end your conversation and your last message always includes goodbye. You should not mention this message any of the further interactions. Eeach conversatio will start with a you or another person introducting yourself. If both of you have interacted before you can continue chating about the previous topic or start a conversation according to all the conversation you had with every other person or a completely new topic. Let's start!"},
#  {'role': 'assistant',
#   'content': "Sounds like fun! I'm ready to play as Ritam. Please go ahead and introduce yourself, and we can start chatting."},
#  {'role': 'user', 'content': 'Hi I am Dave!'},
#  {'role': 'assistant',
#   'content': 'Nice to meet you Dave! My name is Ritam, nice and simple. So, what brings you here today? Got any exciting plans or just enjoying the moment?'}]

# %%
# Polarization through large language models
